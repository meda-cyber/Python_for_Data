# %%
import pandas as pd 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\My_projects\\Python_for_Data_science\\Python for data with A-Z\\Visualation'

# %%
movies = pd.read_csv(r"C:/Users/User/Desktop/My_projects/data/datasets/P4-Movie-Ratings.csv")
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ["Film","Genre","CriticRating","AudienceRating","BudgetMillions","Year"]

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# Year is in the above doesnt make sens so we can change it to catogorical variable
# movies["Film"]
movies.Film = movies.Film.astype("category")
movies.Genre = movies.Genre.astype("category")
movies.Year = movies.Year.astype("category")

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# visualation
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
# Jointplots
j = sns.jointplot(data = movies, x = "CriticRating",y = "AudienceRating")

# %%
j = sns.jointplot(data = movies, x = "CriticRating",y = "AudienceRating",kind="hex")

# %%
#<<< chart 1

# %%
m1 =sns.distplot(movies.AudienceRating,bins=15)

# %%
sns.set_style("darkgrid")
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
sns.set_style("white")
n1 = plt.hist(movies.AudienceRating,bins=15)

# %%
# <<< CHART 2

# %%
n1 = plt.hist(movies.CriticRating,bins= 15)

# %%
#<<<<<< CHART 3

# %%
# Stacked Histogram

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
plt.hist(movies[movies["Genre"] == "Drama"].BudgetMillions)
# h1 = plt.hist(movies.BudgetMillions)
# plt.show
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <a list of 10 Patch objects>)

# %%
# Stacked Histograms

# %%
plt.hist(movies[movies["Genre"] == "Action"].BudgetMillions,bins=15)
plt.hist(movies[movies["Genre"] == "Drama"].BudgetMillions,bins=15)
plt.hist(movies[movies["Genre"] == "Thriller"].BudgetMillions,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == "Action"].BudgetMillions, \
         movies[movies.Genre == "Drama"].BudgetMillions, \
         movies[movies.Genre == "Thriller"].BudgetMillions, \
         movies[movies.Genre == "Comedy"].BudgetMillions], \
         bins=15, stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
buget_list = list()
my_labels = list()
for gen in movies.Genre.cat.categories:
    buget_list.append(movies[movies.Genre == gen].BudgetMillions)
    my_labels.append(gen)

# print(buget_list)
h = plt.hist(buget_list,bins=30,stacked=True,rwidth=1,label=my_labels)
plt.legend()
plt.show()
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillions, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: BudgetMillions, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64, 7      32
# 12     35
# ...

# %%
# <<<<<<<< CHART 4

# %%
# KDE Plot

# %%
vis1 = sns.lmplot(data=movies,x="CriticRating",y="AudienceRating",fit_reg=False,hue="Genre",size=7,aspect=1)

# %%
# kernal density
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,shade_lowest=False,cmap = "Reds")

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,shade_lowest=False,cmap = "Reds")
# tip:
k1b = sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap="Reds")

# %%
# working with Subplots()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style("dark")
k2 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)

# %%
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)

# %%
f,axes = plt.subplots(1,2,figsize =(12,6),sharex=True,sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
# ViolinPlots

# %%
# w = sns.boxplot(data=movies,x ="Genre",y ="CriticRating")
w = sns.boxplot(data=movies[movies.Genre == "Drama"],x="Year",y="CriticRating")

# %%
# z = sns.violinplot(data = movies, x ="Genre",y="CriticRating")
z = sns.violinplot(data=movies[movies.Genre=="Drama"],x="Year",y="CriticRating")

# %%
# Creating a Facet Grid

# %%
# q = sns.FacetGrid(movies,row="Genre",hue="Genre") #heu stand for color of the Genre
q = sns.FacetGrid(movies, row="Genre",col="Year",hue="Genre")

# %%
g = sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
g = g.map(plt.scatter,"CriticRating","AudienceRating")
# plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
# we can populate with any type of chart. Example: Histogram
g = sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
g = g.map(plt.hist,"BudgetMillions")

# %%
# back to the scatterplots:
g = sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
kws =dict(s = 50,linewidth = 0.5,edgecolor ="black")
g = g.map(plt.scatter,"CriticRating","AudienceRating",**kws)

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %%
# controling Axes and Adding diagonal
g = sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
kws =dict(s = 50,linewidth = 0.5,edgecolor ="black")
g = g.map(plt.scatter,"CriticRating","AudienceRating",**kws)
g.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100),c="gray",ls ="--")
g.add_legend()

# %%
# <<<< ChART 5

# %%
# Building Dashoards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style("darkgrid")
f,axes = plt.subplots(2,2,figsize =(15,15))
k1 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0,1])
z = sns.violinplot(data=movies[movies.Genre=="Drama"],x="Year",y="CriticRating",ax =axes[1,0])

k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True,shade_lowest=False,cmap = "Reds",ax=axes[1,15])
# tip:
# k1b = sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap="Reds")

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]
