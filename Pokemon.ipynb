# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\User\Desktop\Pokemon\pokemon_data.csv.txt")
# print(df)
# print(df.head(5))

# %% [markdown]
# # Reading Pandas in Data

# %%
# Read Headers
(df.columns)
# Read each column
# print(df[["Name","Type 1","HP"]])
# Read each Row
# print(df.iloc[1:5])
# for index,row in df.iterrows():
#     print(index,row["Name"])
df.loc[df["Type 1"] == "Fire"]

# Read a specific location(R,C)
# print(df.iloc[2,1])
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# # Sorting/Describing Data

# %%
df.sort_values(["Type 1", "HP"], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making change to the Data

# %%
# df["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] + df["Speed"]

# df = df.drop(columns=["Total"])
df["Total"] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns.values)
df =df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary   Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False   799.0  45
# 1  2                Ivysaur  Grass  Poison           1      False  1015.0  60
# 2  3               Venusaur  Grass  Poison           1      False  1315.0  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False  1595.0  80
# 4  4             Charmander   Fire     NaN           1      False   747.0  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
# df.to_csv("modified.csv", index = False)
# df.to_excel("modified.xlsx", index =False)
df.to_csv("modified.txt", index =False, sep="\t")

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary   Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False   799.0  45
# 1  2                Ivysaur  Grass  Poison           1      False  1015.0  60
# 2  3               Venusaur  Grass  Poison           1      False  1315.0  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False  1595.0  80
# 4  4             Charmander   Fire     NaN           1      False   747.0  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %% [markdown]
# # Filtern Data

# %%
# df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["HP"] > 70)]
# new_df.to_csv("filtered.csv")
#  new_df.reset_index(drop =True, inplace=True)
#  new_df
import re

df.loc[df["Type 1"].str.contains("pi[a-z]", regex=True)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Generation, Legendary, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed]
# Index: []

# %% [markdown]
# # Conditional Changes

# %%
 df= pd.read_csv(r"C:\Users\User\Desktop\modified.csv")
    
    
#  df.loc[df["Total"] > 500, ["Generation", "Legendary"]] = ["Test 1", "Test 2"]
#  df
# df.loc[df["Type 1"] == "Fire", "Legendary"] = "True"

# %% [markdown]
# # Aggregate statistics(Groupby)

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\modified.csv")
df.groupby(["Type 1"]).mean().sort_values("Attack", ascending=False)
# Out:
#           Unnamed: 0           #  Generation  Legendary        Total  \
# Type 1
# Dragon    521.843750  474.375000    3.875000   0.375000  1397.062500
# Fighting  400.444444  363.851852    3.370370   0.000000  1052.481481
# Ground    392.312500  356.281250    3.156250   0.125000  1122.062500
# Rock      431.840909  392.727273    3.454545   0.090909  1174.045455
# Steel     486.296296  442.851852    3.851852   0.148148  1272.111111
# Dark      507.387097  461.354839    4.032258   0.064516  1115.451613
# Fire      360.942308  327.403846    3.211538   0.096154  1153.230769
# Flying    746.500000  677.750000    5.500000   0.500000  1178.000000
# Poison    278.285714  251.785714    2.535714   0.000000  1005.892857
# Water     333.312500  303.089286    2.857143   0.035714  1088.955357
# Ghost     536.281250  486.500000    4.187500   0.062500  1113.593750
# Normal    351.581633  319.173469    3.051020   0.020408   998.244898
# ...
